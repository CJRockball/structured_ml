# %%
from config import ART_DIR
import pandas as pd

df = pd.read_csv(ART_DIR / "run_log.csv")
df.sort_values("mean_cv_metric", ascending=False)
# Out:
#                 date           exp_name  \
# 14  2026-06-26 09:18    tune_stochastic
# 13  2026-06-26 09:12   tune_regularised
# 1   2026-06-25 15:29           xgb1_fe1
# 10  2026-06-26 08:49       tune_base fe
# 16  2026-06-26 14:21          xgb_fe_v1
# 0   2026-06-25 14:16          xgb1_base
# 4   2026-06-26 07:26          tune_base
# 12  2026-06-26 09:06  tune_shallow_fast
# 15  2026-06-26 09:25      tune_balanced
# 7   2026-06-26 07:42   tune_regularised
# 8   2026-06-26 07:47    tune_stochastic
# 6   2026-06-26 07:38  tune_shallow_fast
# 9   2026-06-26 07:52      tune_balanced
# 11  2026-06-26 09:01     tune_deep_slow
# 5   2026-06-26 07:35     tune_deep_slow
# 2   2026-06-25 21:39      tune_lr001_d8
# 3   2026-06-25 22:01   fe_tune_lr001_d8
#
#                                    exp_notes  \
# 14                          baseline xgb run
# 13                          baseline xgb run
# 1                    First run with argparse
# 10                          baseline xgb run
# ...
